# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from functions import clean


df = pd.read_csv("dataset_house_apartment.csv")

# %% [markdown]
# #     Which variable is the target ?

# %% [raw]
# The price (ImmoEliza want to predict the price of somme houses/aparts).

# %%
price_cleaned = clean(df, [3])
# Out:
# price : nbr ligne = 52077
# 51689
# C:\Users\Shadow\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
price_repartition = plt.hist(price_cleaned['price'])

plt.xlabel('Price')
plt.ylabel('Number')
plt.title('Price repartition')
plt.show()

# %% [markdown]
# #     How many rows and columns ?

# %% [raw]
# It depends of the level of cleaning we are doing
# Between 5023 rows (every columns is cleaned, so lot of loss of datas)
# and 52077 (some basic cleaning is done, mostly to make the datas clearer, but few rows are deleted)
# Depending of the datas we have to analyse, we can easily choose wich cleaning we want to do.

# %% [markdown]
# #     What is the correlation between variable/target ? (Why?)

# %% [raw]
# Rel price/locality

# %%
price_locality = clean(df, [0,3])
# Out:
# locality : nbr ligne = 52077
# 52077
# price : nbr ligne = 52077
# 51689

# %%
price_locality.sample(50)
# Out:
#        locality type_of_property   subtype_of_property   price  \
# 15282      8300        apartment           flat studio  250000
# 15016      2560        apartment             apartment  212500
# 37467      5070            house                 house  240000
# 20479      2620        apartment             apartment  283950
# 43899      2560            house                 house  325000
# 22617      8530        apartment             apartment  325000
# 29292      7380            house                 house  110000
# 1065       5660            house                 house  550000
# 3213       9250            house  exceptional property  665000
# 46641      7140            house                 house  390000
# 33137      4900            house                 house  185000
# 42091      5060            house                 villa  265000
# 29282      7320            house                 house  120000
# 14113      9600        apartment             apartment  214000
# 35918      4300            house                 house  249000
# 5557       8420        apartment             apartment  140000
# 6998       8930        apartment             apartment  133000
# 2635       9830            house       apartment block  609000
# 21673      8370        apartment             apartment  335000
# 46971      2381            house                 house  379000
# 3990       8310            house                 house  795000
# 17001      1420        apartment          ground floor  295000
# 35530      8957            house                 house  222871
# 8412       3840        apartment          ground floor  176385
# 34263      7500            house                 house  165000
# 11656      2950        apartment             apartment  185000
# 37368      9100            house                 house  235000
# 17843      8200        apartment                duplex  299000
# 32229      6760            house                 house  160000
# 6450       7301        apartment             apartment  105000
# 20714      1700        apartment             apartment  260800
# 23588      8300        apartment             apartment  398000
# 48616      3128            house                 house  394980
# 1348       2360            house                 villa  550000
# 26363      6000        apartment             apartment  579000
# 11190      1140        apartment             apartment  169000
# 35322      9890            house                 house  225000
# 13238      8954        apartment             apartment  240000
# 48071      7700            house                 villa  389000
# 42758      8700            house                 house  281900
# 47708      2600            house       apartment block  385000
# 20817      1000        apartment             apartment  337000
# 14417      7160        apartment             apartment  230000
# 11755      3640        apartment             apartment  186400
# 7229       3970        apartment             apartment  129000
# 18792      8370        apartment             apartment  299750
# 10413      2600        apartment             apartment  178000
# 29918      7080            house                 house  115000
# 16977      1180        apartment             apartment  284500
# 6450         1            14       0            0                  0.0
# 20714        1            12       1           68                  0.0
# 23588        1             0       0            0                  0.0
# 48616        0             0       1            0               2005.0
# 1348         0             0       1            0               2195.0
# 26363        0             0       0            0                  0.0
# 11190        1            11       0            0                  0.0
# 35322        0             0       1           40                160.0
# 13238        0             0       0            0                  0.0
# 48071        1            60       1         1200               2020.0
# 42758        1             0       0            0                600.0
# 47708        0             0       0            0                 70.0
# 20817        1            14       0            0                  0.0
# 14417        0             0       1            0                  0.0
# 11755        0             0       0            0                  0.0
# 7229         1             0       0            0                  0.0
# 18792        0             0       1            0                  0.0
# 10413        1            18       0            0                  0.0
# 29918        0             0       1            0                204.0
# 16977        1             6       0            0                  0.0
# 7678         0             0       0            0                  0.0
#
#        number_of_facades  swimming_pool state_of_the_building  \
# 15282                  2              0                     0
# 15016                  3              0                as new
# 37467                  4              0                     0
# 20479                  0              0                as new
# 43899                  3              0                as new
# 22617                  0              0                as new
# 29292                  3              0           to renovate
# 1065                   4              0                  good
# 3213                   3              0        just renovated
# 46641                  0              0                as new
# 33137                  2              0                  good
# 42091                  4              0                  good
# 29282                  2              0                     0
# 14113                  0              0                     0
# 35918                  2              0                     0
# 5557                   0              0                  good
# 6998                   2              0                  good
# 2635                   3              0                     0
# 21673                  2              0                     0
# 46971                  4              0                     0
# 3990                   2              0                  good
# 17001                  0              0                as new
# 35530                  2              0                as new
# 8412                   0              0                as new
# 34263                  2              0                     0
# 11656                  0              0           to renovate
# 37368                  2              0        just renovated
# 17843                  0              0                as new
# 32229                  3              0                     0
# 6450                   0              0                  good
# 20714                  0              0                     0
# 23588                  0              0                as new
# 48616                  0              0                as new
# 1348                   4              0           to renovate
# 26363                  2              0                  good
# 11190                  2              0                     0
# 35322                  0              0                  good
# 13238                  0              0                     0
# 48071                  4              0                  good
# 42758                  3              0                  good
# 47708                  2              0                     0
# 20817                  0              0                as new
# 14417                  3              0                as new
# 11755                  2              0                     0
# 7229                   2              0                as new
# 18792                  2              0                  good
# 10413                  2              0                  good
# 29918                  3              0                  good
# 16977                  4              0                     0
# 7678                   2              0                  good
#
#        construction_year             province                        region
# 15282               2001  Flandre-Occidentale               Region Flamande
# 15016               2020               Anvers               Region Flamande
# 37467               1970                Namur               Region Wallonne
# 20479                  0               Anvers               Region Flamande
# 43899                  0               Anvers               Region Flamande
# 22617                  0  Flandre-Occidentale               Region Flamande
# 29292                  0              Hainaut               Region Wallonne
# 1065                   0                Namur               Region Wallonne
# 3213                1800    Flandre-Orientale               Region Flamande
# 46641                  0              Hainaut               Region Wallonne
# 33137                  0                Liege               Region Wallonne
# 42091               1976                Namur               Region Wallonne
# 29282                  0              Hainaut               Region Wallonne
# 14113               2019    Flandre-Orientale               Region Flamande
# 35918                  0                Liege               Region Wallonne
# 5557                   0  Flandre-Occidentale               Region Flamande
# 6998                2018  Flandre-Occidentale               Region Flamande
# 2635                   0    Flandre-Orientale               Region Flamande
# 21673               2019  Flandre-Occidentale               Region Flamande
# 46971               2005               Anvers               Region Flamande
# 3990                1918  Flandre-Occidentale               Region Flamande
# 17001               2005       Brabant Wallon               Region Wallonne
# 35530               2019  Flandre-Occidentale               Region Flamande
# 8412                2020             Limbourg               Region Flamande
# 34263                  0              Hainaut               Region Wallonne
# 11656                  0               Anvers               Region Flamande
# 37368               1850    Flandre-Orientale               Region Flamande
# 17843               2020  Flandre-Occidentale               Region Flamande
# 32229                  0           Luxembourg               Region Wallonne
# 6450                1980              Hainaut               Region Wallonne
# 20714                  0      Brabant Flamand               Region Flamande
# 23588               2018  Flandre-Occidentale               Region Flamande
# 48616                  0      Brabant Flamand               Region Flamande
# 1348                1974               Anvers               Region Flamande
# 26363               1965              Hainaut               Region Wallonne
# 11190               1970            Bruxelles  Region de Bruxelles-capitale
# 35322                  0    Flandre-Orientale               Region Flamande
# 13238               2019  Flandre-Occidentale               Region Flamande
# 48071               1960              Hainaut               Region Wallonne
# 42758               1930  Flandre-Occidentale               Region Flamande
# 47708               1935               Anvers               Region Flamande
# 20817               2019            Bruxelles  Region de Bruxelles-capitale
# 14417               2006              Hainaut               Region Wallonne
# 11755                  0             Limbourg               Region Flamande
# 7229                2009             Limbourg               Region Flamande
# 18792               2007  Flandre-Occidentale               Region Flamande
# 10413               1975               Anvers               Region Flamande
# 29918                  0              Hainaut               Region Wallonne
# 16977               2019            Bruxelles  Region de Bruxelles-capitale
# 7678                1969  Flandre-Occidentale               Region Flamande

# %%
price_locality.sort_values('price')
plt.plot(price_locality.locality , price_locality.price)

# %%
bxl_df = price_locality[price_locality['region'] == 'Region de Bruxelles-capitale'].price
plt.hist(bxl_df, bins=25, color="blue", alpha=0.5)
wal_df = price_locality[price_locality['region'] == 'Region Wallonne'].price
plt.hist(wal_df, bins=25, color="red", alpha=0.5)
fla_df = price_locality[price_locality['region'] == 'Region Flamande'].price
plt.hist(fla_df, bins=25, color="yellow", alpha=0.5)
plt.xlabel('Price')
plt.ylabel('Number')
plt.title('Price repartition')

plt.show()

# %%
price_region = price_locality[price_locality['region'=='Region Wallonne']]

price_region
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-869214451e26> in <module>
# ----> 1 price_region = price_locality[price_locality['region'=='Region Wallonne']]
#       2
#       3 price_region
#       4
#       5 # price_region.plot(y='price')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False

# %% [markdown]
# #     What is the correlation between the variables/variables ? (Why?)

# %% [markdown]
# #     Which variables have the greatest influence on the target ?

# %% [markdown]
# #     Which variables have the least influence on the target ?

# %% [markdown]
# #     How many qualitative and quantitative variable is there ? How would you transform these values into numerical values ?

# %% [markdown]
# #     Percentage of missing values per column ?
