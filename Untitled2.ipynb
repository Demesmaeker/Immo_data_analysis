# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from functions import clean


df = pd.read_csv("dataset_house_apartment.csv")

# %%
data = clean(df)
# Out:
# {0: 'locality', 1: 'type_of_property', 2: 'subtype_of_property', 3: 'price', 4: 'type_of_sale', 5: 'number_of_rooms', 6: 'house_area', 7: 'fully_equipped_kitchen', 8: 'furnished', 9: 'open_fire', 10: 'terrace', 11: 'terrace_area', 12: 'garden', 13: 'garden_area', 14: 'surface_of_the_land', 15: 'surface_of_the_plot_of_land', 16: 'number_of_facades', 17: 'swimming_pool', 18: 'state_of_the_building', 19: 'construction_year'}
# que voulez-vous clean ? ( q => sortir  // a => tous)a
# locality : nbr ligne = 52077
# 52077
# type_of_property : nbr ligne = 52077
# 52077
# subtype_of_property : nbr ligne = 52077
# 52077
# price : nbr ligne = 52077
# 51689
# type_of_sale : nbr ligne = 51689
# 51689
# number_of_rooms : nbr ligne = 51689
# 43201
# house_area : nbr ligne = 43201
# 43201
# fully_equipped_kitchen : nbr ligne = 43201
# 43201
# furnished : nbr ligne = 43201
# 33629
# open_fire : nbr ligne = 33629
# 33629
# terrace : nbr ligne = 33629
# 29727
# terrace_area : nbr ligne = 29727
# 29727
# ...

# %%
data
# Out:
#        locality type_of_property subtype_of_property   price  number_of_rooms  \
# 1          1880            house               villa  525000              6.0
# 3          7912            house               villa  550000              4.0
# 4          6032            house               house  550000              5.0
# 6          1325            house               house  535000              6.0
# 9          8310            house               villa  519000              3.0
# ...         ...              ...                 ...     ...              ...
# 51933      9870            house               villa  485000              4.0
# 51966      1980            house               house  490000              5.0
# 51975      9870            house               villa  495000              2.0
# 51983      2610            house               house  495000              3.0
# 52017      3520            house               house  499000              4.0
#
# ...

# %%
data.type_of_property.value_counts()
# Out:
# house    5023
# Name: type_of_property, dtype: int64

# %%
locality_price = data.groupby("locality").price.agg(["mean"])

# %%
locality_price
# Out:
#                    mean
# locality
# 1000      672000.000000
# 1020      494733.333333
# 1030      553615.384615
# 1040      708785.714286
# 1050      710500.000000
# ...                 ...
# 9968      795000.000000
# 9970      218602.000000
# 9988      204800.000000
# 9990      437698.000000
# 9992      695000.000000
#
# [824 rows x 1 columns]

# %%
province_price = data.groupby("province").price.agg(["mean"])

# %%
province_price
# Out:
#                               mean
# province
# Anvers               390453.020380
# Brabant Flamand      438884.094656
# Brabant Wallon       460171.994083
# Bruxelles            584014.324042
# Flandre-Occidentale  347790.074954
# Flandre-Orientale    361383.697115
# Hainaut              256155.635789
# Liege                304529.552398
# Limbourg             309427.134884
# Luxembourg           308616.566265
# Namur                316397.029703

# %%
province_price.reset_index(level=0, inplace=True)

# %%
province_price.plot.bar(x = "province", y = "mean")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5023 entries, 1 to 52017
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   locality                5023 non-null   int64
#  1   type_of_property        5023 non-null   object
#  2   subtype_of_property     5023 non-null   object
#  3   price                   5023 non-null   int64
#  4   number_of_rooms         5023 non-null   float64
#  5   house_area              5023 non-null   int64
#  6   fully_equipped_kitchen  5023 non-null   int64
#  7   open_fire               5023 non-null   int64
#  8   terrace                 5023 non-null   int64
#  9   terrace_area            5023 non-null   int64
#  10  garden                  5023 non-null   int64
#  11  garden_area             5023 non-null   int64
#  12  surface_of_the_land     5023 non-null   float64
#  13  number_of_facades       5023 non-null   int64
# ...
