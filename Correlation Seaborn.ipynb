# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

from functions import clean


df = pd.read_csv("dataset_house_apartment.csv")

# %%
df = clean(df)
# Out:
# {0: 'locality', 1: 'type_of_property', 2: 'subtype_of_property', 3: 'price', 4: 'type_of_sale', 5: 'number_of_rooms', 6: 'house_area', 7: 'fully_equipped_kitchen', 8: 'furnished', 9: 'open_fire', 10: 'terrace', 11: 'terrace_area', 12: 'garden', 13: 'garden_area', 14: 'surface_of_the_land', 15: 'surface_of_the_plot_of_land', 16: 'number_of_facades', 17: 'swimming_pool', 18: 'state_of_the_building', 19: 'construction_year'}
# que voulez-vous clean ? ( q => sortir  // a => tous)a
# locality : nbr ligne = 52077
# 52077
# type_of_property : nbr ligne = 52077
# 52077
# subtype_of_property : nbr ligne = 52077
# 52077
# price : nbr ligne = 52077
# 51689
# type_of_sale : nbr ligne = 51689
# 51689
# number_of_rooms : nbr ligne = 51689
# 51689
# house_area : nbr ligne = 51689
# 43201
# fully_equipped_kitchen : nbr ligne = 43201
# 43201
# furnished : nbr ligne = 43201
# 43201
# open_fire : nbr ligne = 43201
# 43201
# terrace : nbr ligne = 43201
# 33629
# terrace_area : nbr ligne = 33629
# 33629
# garden : nbr ligne = 33629
# 29727
# garden_area : nbr ligne = 29727
# 29727
# surface_of_the_land : nbr ligne = 29727
# 12322
# surface_of_the_plot_of_land : nbr ligne = 12322
# 12322
# number_of_facades : nbr ligne = 12322
# 11146
# /Users/noahalvarezgonzalez/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# /Users/noahalvarezgonzalez/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11146 entries, 1 to 52068
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   locality                11146 non-null  int64
#  1   type_of_property        11146 non-null  object
#  2   subtype_of_property     11146 non-null  object
#  3   price                   11146 non-null  int64
#  4   number_of_rooms         11146 non-null  float64
#  5   house_area              11146 non-null  int64
#  6   fully_equipped_kitchen  11146 non-null  int64
#  7   open_fire               11146 non-null  int64
#  8   terrace                 11146 non-null  int64
#  9   terrace_area            11146 non-null  int64
#  10  garden                  11146 non-null  int64
#  11  garden_area             11146 non-null  int64
#  12  surface_of_the_land     11146 non-null  float64
#  13  number_of_facades       11146 non-null  int64
#  14  swimming_pool           11146 non-null  int64
#  15  state_of_the_building   11146 non-null  object
#  16  construction_year       11146 non-null  int64
#  17  province                11146 non-null  object
#  18  region                  11146 non-null  object
# dtypes: float64(2), int64(12), object(5)
# memory usage: 1.7+ MB

# %%
df.corr()
# Out:
#                         locality     price  number_of_rooms  house_area  \
# locality                1.000000 -0.270268        -0.087608   -0.043428
# price                  -0.270268  1.000000         0.393711    0.497782
# number_of_rooms        -0.087608  0.393711         1.000000    0.464891
# house_area             -0.043428  0.497782         0.464891    1.000000
# fully_equipped_kitchen -0.021000  0.051258         0.021024   -0.034938
# open_fire              -0.043112  0.200755         0.079334    0.114372
# terrace                -0.119564  0.155611         0.085031    0.024812
# terrace_area           -0.053375  0.203485         0.140259    0.139520
# garden                 -0.064901  0.093998         0.056253    0.003097
# garden_area            -0.021152  0.177246         0.093702    0.167023
# surface_of_the_land     0.003064  0.202526         0.088289    0.216404
# number_of_facades      -0.024171  0.252524         0.100395    0.173336
# swimming_pool          -0.040571  0.170570         0.069250    0.111183
# construction_year      -0.101815  0.250387         0.053417    0.053910
#
#                         fully_equipped_kitchen  open_fire   terrace  \
# locality                             -0.021000  -0.043112 -0.119564
# price                                 0.051258   0.200755  0.155611
# number_of_rooms                       0.021024   0.079334  0.085031
# house_area                           -0.034938   0.114372  0.024812
# fully_equipped_kitchen                1.000000   0.107619  0.234974
# open_fire                             0.107619   1.000000  0.135005
# terrace                               0.234974   0.135005  1.000000
# terrace_area                          0.141261   0.122407  0.578789
# garden                                0.216672   0.145769  0.406889
# garden_area                           0.052680   0.120862  0.112169
# surface_of_the_land                  -0.022835   0.073054  0.001886
# number_of_facades                    -0.011160   0.146216  0.030740
# swimming_pool                         0.051354   0.107747  0.102003
# construction_year                     0.095885   0.100727  0.135476
#
#                         terrace_area    garden  garden_area  \
# locality                   -0.053375 -0.064901    -0.021152
# price                       0.203485  0.093998     0.177246
# number_of_rooms             0.140259  0.056253     0.093702
# house_area                  0.139520  0.003097     0.167023
# fully_equipped_kitchen      0.141261  0.216672     0.052680
# open_fire                   0.122407  0.145769     0.120862
# terrace                     0.578789  0.406889     0.112169
# terrace_area                1.000000  0.242781     0.166931
# garden                      0.242781  1.000000     0.279915
# garden_area                 0.166931  0.279915     1.000000
# surface_of_the_land         0.077705 -0.010269     0.319696
# number_of_facades           0.144870  0.034673     0.203582
# swimming_pool               0.175736  0.072753     0.099911
# construction_year           0.093694  0.138238     0.028291
#
#                         surface_of_the_land  number_of_facades  swimming_pool  \
# locality                           0.003064          -0.024171      -0.040571
# price                              0.202526           0.252524       0.170570
# number_of_rooms                    0.088289           0.100395       0.069250
# house_area                         0.216404           0.173336       0.111183
# fully_equipped_kitchen            -0.022835          -0.011160       0.051354
# open_fire                          0.073054           0.146216       0.107747
# terrace                            0.001886           0.030740       0.102003
# terrace_area                       0.077705           0.144870       0.175736
# garden                            -0.010269           0.034673       0.072753
# garden_area                        0.319696           0.203582       0.099911
# surface_of_the_land                1.000000           0.233373       0.065253
# number_of_facades                  0.233373           1.000000       0.130644
# swimming_pool                      0.065253           0.130644       1.000000
# construction_year                  0.002323           0.170910       0.051188
#
#                         construction_year
# locality                        -0.101815
# price                            0.250387
# number_of_rooms                  0.053417
# house_area                       0.053910
# fully_equipped_kitchen           0.095885
# open_fire                        0.100727
# terrace                          0.135476
# terrace_area                     0.093694
# garden                           0.138238
# garden_area                      0.028291
# surface_of_the_land              0.002323
# number_of_facades                0.170910
# swimming_pool                    0.051188
# construction_year                1.000000

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52077 entries, 0 to 52076
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   locality                     52077 non-null  int64
#  1   type_of_property             52077 non-null  object
#  2   subtype_of_property          52077 non-null  object
#  3   price                        52077 non-null  object
#  4   type_of_sale                 52077 non-null  object
#  5   number_of_rooms              52075 non-null  float64
#  6   house_area                   52077 non-null  object
#  7   fully_equipped_kitchen       52077 non-null  int64
#  8   furnished                    52077 non-null  object
#  9   open_fire                    52077 non-null  int64
#  10  terrace                      52077 non-null  int64
#  11  terrace_area                 52077 non-null  object
#  12  garden                       52077 non-null  int64
#  13  garden_area                  52077 non-null  object
#  14  surface_of_the_land          29353 non-null  float64
#  15  surface_of_the_plot_of_land  52077 non-null  object
#  16  number_of_facades            52077 non-null  object
#  17  swimming_pool                52077 non-null  int64
#  18  state_of_the_building        52077 non-null  object
#  19  construction_year            52077 non-null  object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 7.9+ MB

# %%
plt.figure(figsize=(12,12))
seaborn.heatmap(df.corr(), annot=True, cmap="coolwarm")
